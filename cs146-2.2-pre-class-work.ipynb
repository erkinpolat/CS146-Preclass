# %% [markdown]
# # Call center data modeling
#
# You are advising a client on the number of call center agents they need to handle their customer support load. We start by modeling the number of phone calls we expect to come into the call center during each hour of the day.
#
# You are provided with a data set of the intervals between phone calls arriving during one day. Each value is a time in minutes indicating the amount of time that passed between receiving two consecutive phone calls.
#
# ## Loading the data

# %%
import numpy as np
import scipy as sp
from scipy import stats
import scipy.stats as sts
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#Task 1

#Gamma

# Set up the probability distribution
alpha = 2
beta = 1
distribution = stats.gamma(a=alpha, scale=1/beta)

# Plot the pdf
plt.figure(figsize=(8, 4))
x = np.linspace(0, 5)
plt.plot(x, distribution.pdf(x))
plt.title('probability density function')

# Set up the probability distribution
alpha = 3
beta = 2
distribution = stats.gamma(a=alpha, scale=1/beta)

# Plot the pdf
plt.figure(figsize=(8, 4))
x = np.linspace(0, 5)
plt.plot(x, distribution.pdf(x))
plt.title('probability density function')

# Plot a histogram of random samples
samples = distribution.rvs(size=100)
plt.figure(figsize=(8, 4))
plt.hist(samples, range=[0, 5], density=True)
plt.plot(x, distribution.pdf(x))
plt.title('histogram of random samples')

#Normal

# Set up the probability distribution
mu = 2
sigma = 2
distribution = stats.norm(loc=mu, scale=sigma)

# Plot the pdf
plt.figure(figsize=(8, 4))
x = np.linspace(-5, 10)
plt.plot(x, distribution.pdf(x))
plt.title('probability density function')

# Set up the probability distribution
mu = 0
sigma = 1
distribution = stats.norm(loc=mu, scale=sigma)

# Plot the pdf
plt.figure(figsize=(8, 4))
x = np.linspace(-5, 5)
plt.plot(x, distribution.pdf(x))
plt.title('probability density function')

# Plot a histogram of random samples
samples = distribution.rvs(size=100)
plt.figure(figsize=(8, 4))
plt.hist(samples, range=[-5, 5], density=True)
plt.plot(x, distribution.pdf(x))
plt.title('histogram of random samples')

#Beta

# Set up the probability distribution
alpha = 0
beta = 1
distribution = stats.beta(a=alpha, b=beta)

# Plot the pdf
plt.figure(figsize=(8, 4))
x = np.linspace(0, 5)
plt.plot(x, distribution.pdf(x))
plt.title('probability density function')

# Set up the probability distribution
alpha = 0
beta = 1
distribution = stats.beta(a=alpha, b=beta)

# Plot the pdf
plt.figure(figsize=(8, 4))
x = np.linspace(0, 5)
plt.plot(x, distribution.pdf(x))
plt.title('probability density function')

# Plot a histogram of random samples
samples = distribution.rvs(size=100)
plt.figure(figsize=(8, 4))
plt.hist(samples, range=[0, 5], density=True)
plt.plot(x, distribution.pdf(x))
plt.title('histogram of random samples')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-0afafae3061b> in <module>
#      88
#      89 # Plot a histogram of random samples
# ---> 90 samples = distribution.rvs(size=100)
#      91 plt.figure(figsize=(8, 4))
#      92 plt.hist(samples, range=[0, 5], density=True)
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py in rvs(self, size, random_state)
#     461         kwds = self.kwds.copy()
#     462         kwds.update({'size': size, 'random_state': random_state})
# --> 463         return self.dist.rvs(*self.args, **kwds)
#     464
#     465     def sf(self, x):
#
# /usr/local/lib/python3.6/dist-packages/scipy/stats/_distn_infrastructure.py in rvs(self, *args, **kwds)
#     960         cond = logical_and(self._argcheck(*args), (scale >= 0))
#     961         if not np.all(cond):
# --> 962             raise ValueError("Domain error in arguments.")
#     963
#     964         if np.all(scale == 0):
#
# ValueError: Domain error in arguments.

# %%
# Load the data set containing durations between calls arriving at the call
# center during 1 day. All values are in minutes.
waiting_times_day = np.loadtxt('call_center.csv')

# Display some basic information about the data set.
print('Size of data set:', len(waiting_times_day))
print('First 3 values in data set:', waiting_times_day[:3])
print('Sum of data set:', sum(waiting_times_day))
# Out:
# Size of data set: 5856
# First 3 values in data set: [30.   3.4  3.2]
# Sum of data set: 1441.6838153800093

# %% [markdown]
# Since the values are intervals between calls measured in minutes, this means
#
# * we assume the first call happened at 00:00 (midnight),
# * the second call happened at about 00:30 (30 minutes after midnight),
# * the third call happened at about 00:33 (30 + 3.4 minutes),
# * the fourth call happened at about 00:37, etc.
#
# When we sum the values, we get about 1440 minutes (1 day).

# %% [markdown]
# You are told that the number of calls arriving varies quite a lot, depending on which hour of the day it is. The smallest number of calls usually occur around 3am or 4am. Most calls usually come in between 11am and 1pm.
#
# ## Data pre-processing
# Since we expect different call rates during different hours, we split the data set into 24 separate series — one for each hour of the day.

# %%
# Make 24 empty lists, one per hour.
waiting_times_per_hour = [[] for _ in range(24)]

# Split the data into 24 separate series, one for each hour of the day.
current_time = 0
for t in waiting_times_day:
    current_hour = int(current_time // 60)
    current_time += t
    waiting_times_per_hour[current_hour].append(t)

for hour, calls_in_hour in enumerate(waiting_times_per_hour):
    print(f'{hour:02}:00-{hour + 1:02}:00 - {len(calls_in_hour)} calls')
# Out:
# 00:00-01:00 - 5 calls
# 01:00-02:00 - 4 calls
# 02:00-03:00 - 6 calls
# 03:00-04:00 - 8 calls
# 04:00-05:00 - 26 calls
# 05:00-06:00 - 53 calls
# 06:00-07:00 - 93 calls
# 07:00-08:00 - 173 calls
# 08:00-09:00 - 254 calls
# 09:00-10:00 - 345 calls
# 10:00-11:00 - 496 calls
# 11:00-12:00 - 924 calls
# 12:00-13:00 - 858 calls
# 13:00-14:00 - 382 calls
# 14:00-15:00 - 185 calls
# 15:00-16:00 - 207 calls
# 16:00-17:00 - 263 calls
# 17:00-18:00 - 419 calls
# 18:00-19:00 - 531 calls
# 19:00-20:00 - 400 calls
# 20:00-21:00 - 137 calls
# 21:00-22:00 - 51 calls
# 22:00-23:00 - 20 calls
# 23:00-24:00 - 16 calls

# %% [markdown]
# ## Task 1: Plot the number of calls per hour
# Use Matplotlib to visualize the number of calls that arrive during each hour of the day, stored in the variable `waiting_times_per_hour`. The call numbers are shown in the output above. You should find an appropriate way to visualize it.

# %%
for hour, calls_in_hour in enumerate(waiting_times_per_hour):
    a = hour
    b = calls_in_hour
    
plt.plot(a, b)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-8e01b82c1923> in <module>
#       3     b = calls_in_hour
#       4
# ----> 5 plt.plot(a, b)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2793     return gca().plot(
#    2794         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2795         is not None else {}), **kwargs)
#    2796
#    2797
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (1,) and (16,)

# %% [markdown]
# ## Task 2: Plot a histogram of the durations for one hour
# Take the data for the 9th hour (so between 9am and 10am) and plot a histogram showing the distribution over waiting times between calls during that hour.

# %%
plt.hist(waiting_times_per_hour)
# Out:
# ([array([1., 2., 0., 0., 0., 0., 0., 1., 0., 1.]),
#   array([0., 1., 0., 0., 1., 0., 0., 2., 0., 0.]),
#   array([1., 1., 1., 0., 1., 0., 0., 1., 1., 0.]),
#   array([4., 3., 0., 0., 0., 1., 0., 0., 0., 0.]),
#   array([18.,  6.,  2.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]),
#   array([50.,  2.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]),
#   array([92.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]),
#   array([173.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([254.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([345.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([496.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([924.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([858.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([382.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([185.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([207.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([263.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([419.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([531.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([400.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([137.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.]),
#   array([46.,  4.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]),
#   array([13.,  4.,  3.,  0.,  0.,  0.,  0.,  0.,  0.,  0.]),
#   array([9., 5., 0., 1., 1., 0., 0., 0., 0., 0.])],
#  array([6.80000000e-07, 3.00000061e+00, 6.00000054e+00, 9.00000048e+00,
#         1.20000004e+01, 1.50000003e+01, 1.80000003e+01, 2.10000002e+01,
#         2.40000001e+01, 2.70000001e+01, 3.00000000e+01]),
#  <a list of 24 Lists of Patches objects>)

# %% [markdown]
# ## Task 3: Guess the distribution
# What type of distribution best represents the data in your histogram?
#
# * Identify a type of distribution. **In class you will use this distribution as your likelihood function in a Bayesian inference problem.**
# * Guess what the parameters of the distribution are. (This is just a guess for now. In class we will infer the values of the parameters.)
# * Plot the pdf of your best guess on top of your histogram, to see if they match.
# * **Important:** You have to normalize your histogram so that it will have the same vertical scale as the plot of the pdf. You can normalize a histogram by using the argument `density=True` in the `hist` function.

# %%
#let's guess that it is a gamma distribution

# Set up the probability distribution
alpha = 2
beta = 1
distribution = stats.gamma(a=alpha, scale=1/beta)

# Plot the pdf
plt.figure(figsize=(8, 4))
x = np.linspace(0, 5)
plt.plot(x, distribution.pdf(x))
plt.hist(waiting_times_per_hour, density=True)
plt.title('probability density function')
# Out:
# Text(0.5, 1.0, 'probability density function')
